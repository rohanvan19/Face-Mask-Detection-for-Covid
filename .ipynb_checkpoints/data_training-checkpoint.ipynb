# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\rohan vanmali\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\rohan vanmali\anaconda3\lib\site-packages (from opencv-python) (1.20.3)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('theoffice.jpg')

# %%
print(img.shape)
# Out:
# (676, 1238, 3)

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow('The Office',img)
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()

# %%
haar_data = cv2.CascadeClassifier('data.xml')

# %%
haar_data.detectMultiScale(img)
# Out:
# array([[ 810,   76,   83,   83],
#        [1074,  173,  101,  101],
#        [ 121,  107,  115,  115],
#        [ 566,  118,   90,   90],
#        [1083,  334,   25,   25],
#        [ 253,   66,   89,   89]])

# %%
while True:
    faces = haar_data.detectMultiScale(img)
    for x,y,w,h in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,255), 4)
    cv2.imshow('Output',img)
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()

# %%
capture = cv2.VideoCapture('officevideo.mp4')
data = []
while True:
    flag, img = capture.read()
    if flag:
        faces = haar_data.detectMultiScale(img)
        for x, y, w, h in faces:
            cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 255), 4)
            face = img[y:y+h, x:x+w, :]
            face = cv2.resize(face, (50,50))
            print(len(data))
            if len(data) < 400:
                data.append(face)
        cv2.imshow('result', img)
        if cv2.waitKey(2) == 27 or len(data) >= 200:
            break
capture.release()
cv2.destroyAllWindows()
